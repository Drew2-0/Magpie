# %% [markdown]
# <a href="https://colab.research.google.com/github/Drew2-0/Magpie/blob/main/Assingment_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Assignment 10: Question 1
heartrate1 = 90
heartrate2 = 67
percent_change = (heartrate2 - heartrate1) / heartrate1 * 100
print("The change in heart rate is", percent_change, "percent.")

#Assignment 10: Question 2a
price1 = 1.50
price2 = 2.00
price3 = 2.50

quantity1 = 2
quantity2 = 1
quantity3 = 3

subtotal = (price1 * quantity1) + (price2 * quantity2) + (price3 * quantity3)

tax_rate = 0.065
tax = subtotal * tax_rate

total = subtotal + tax

print("The tax amount is $", tax)
print("The subtotal is $", subtotal)
print("The total cost of the items is $", total)

#Assignment 10: Question 2b
price1 = 1.50
price2 = 2.00
price3 = 2.50

quantity1 = 2
quantity2 = 1
quantity3 = 3

total_donuts = (quantity1 + quantity2 + quantity3)

discount_rate = 0.05
if total_donuts > 12:
    discount_rate = .05
    discount = (price1 * quantity1 + price2 * quantity2 + price3 * quantity3) * discount_rate
else:
    discount_rate = 0
    discount = (price1 * quantity1 + price2 * quantity2 + price3 * quantity3) * discount_rate

subtotal = (price1 * quantity1) + (price2 * quantity2) + (price3 * quantity3)

tax_rate = 0.065
tax = subtotal * tax_rate

total = subtotal + tax - discount
print("The discount amount is $", discount)
print("The tax amount is $", tax)
print("The subtotal is $", subtotal)
print("The total cost of the items is $", total)

#Assignment 10: Question 3
Ski_Resorts = ["Mount Spokane", "49 Degrees North", "Silver Mountain"]
print("The three ski resorts near Spokane, WA are", ", ".join(Ski_Resorts) + ".")

#Assignment 10: Question 4
import pandas as pd
data = {
    'Name': ['Andrew'],
    'Favorite Restaurant': ['San Blas'],
    'Favorite Sports': ['Rowing'],
    'City': ['West Linn OR']
}
date = pd.DataFrame(data)
print(date)
# Out:
# The change in heart rate is -25.555555555555554 percent.
# The tax amount is $ 0.8125
# The subtotal is $ 12.5
# The total cost of the items is $ 13.3125
# The discount amount is $ 0.0
# The tax amount is $ 0.8125
# The subtotal is $ 12.5
# The total cost of the items is $ 13.3125
# The three ski resorts near Spokane, WA are Mount Spokane, 49 Degrees North, Silver Mountain.
#      Name Favorite Restaurant Favorite Sports          City
# 0  Andrew            San Blas          Rowing  West Linn OR
